# %%
# !mamba install -y pandarallel
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.17.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandarallel']
#
# WARNING conda.lock:touch(51): Failed to create lock, do not run conda in parallel processes [errno 13]
# conda-forge/noarch       [<=>                 ] (00m:00s)
# conda-forge/noarch       [=>                ] (00m:00s) 15  B / ?? (21.00  B/s)
# conda-forge/noarch       [=>                ] (00m:00s) 15  B / ?? (21.00  B/s)
# conda-forge/linux-aarch6 [<=>                 ] (00m:00s)
# conda-forge/noarch       [=>                ] (00m:00s) 15  B / ?? (21.00  B/s)
# conda-forge/linux-aarch6 [=>                ] (00m:00s) 62 KB / ?? (72.81 KB/s)
# conda-forge/noarch       [<=>               ] (00m:00s) 15  B / ?? (21.00  B/s)
# conda-forge/linux-aarch6 [=>                ] (00m:00s) 62 KB / ?? (72.81 KB/s)
# conda-forge/noarch       [<=>               ] (00m:00s) 19 KB / ?? (21.77 KB/s)
# conda-forge/linux-aarch6 [=>                ] (00m:00s) 62 KB / ?? (72.81 KB/s)
# conda-forge/noarch       [<=>               ] (00m:00s) 19 KB / ?? (21.77 KB/s)
# conda-forge/linux-aarch6 [<=>               ] (00m:00s) 62 KB / ?? (72.81 KB/s)
# conda-forge/noarch       [<=>               ] (00m:00s) 19 KB / ?? (21.77 KB/s)
# conda-forge/linux-aarch6 [<=>             ] (00m:00s) 106 KB / ?? (105.22 KB/s)
# conda-forge/noarch       [ <=>              ] (00m:00s) 19 KB / ?? (21.77 KB/s)
# conda-forge/linux-aarch6 [<=>             ] (00m:00s) 106 KB / ?? (105.22 KB/s)
# conda-forge/noarch       [ <=>              ] (00m:00s) 43 KB / ?? (42.29 KB/s)
# conda-forge/linux-aarch6 [<=>             ] (00m:00s) 106 KB / ?? (105.22 KB/s)
# conda-forge/noarch       [ <=>              ] (00m:00s) 43 KB / ?? (42.29 KB/s)
# conda-forge/linux-aarch6 [ <=>            ] (00m:00s) 106 KB / ?? (105.22 KB/s)
# conda-forge/noarch       [ <=>              ] (00m:00s) 43 KB / ?? (42.29 KB/s)
# conda-forge/linux-aarch6 [ <=>            ] (00m:00s) 215 KB / ?? (185.04 KB/s)
# conda-forge/noarch       [  <=>             ] (00m:00s) 43 KB / ?? (42.29 KB/s)
# conda-forge/linux-aarch6 [ <=>            ] (00m:00s) 215 KB / ?? (185.04 KB/s)
# conda-forge/noarch       [  <=>             ] (00m:00s) 62 KB / ?? (53.71 KB/s)
# conda-forge/linux-aarch6 [ <=>            ] (00m:00s) 215 KB / ?? (185.04 KB/s)
# conda-forge/noarch       [  <=>             ] (00m:00s) 62 KB / ?? (53.71 KB/s)
# conda-forge/linux-aarch6 [  <=>           ] (00m:00s) 215 KB / ?? (185.04 KB/s)
# conda-forge/noarch       [  <=>             ] (00m:00s) 62 KB / ?? (53.71 KB/s)
# conda-forge/linux-aarch6 [  <=>           ] (00m:00s) 344 KB / ?? (262.07 KB/s)
# conda-forge/noarch       [   <=>            ] (00m:00s) 62 KB / ?? (53.71 KB/s)
# conda-forge/linux-aarch6 [  <=>           ] (00m:00s) 344 KB / ?? (262.07 KB/s)
# conda-forge/noarch       [   <=>            ] (00m:00s) 86 KB / ?? (65.52 KB/s)
# conda-forge/linux-aarch6 [  <=>           ] (00m:00s) 344 KB / ?? (262.07 KB/s)
# conda-forge/noarch       [   <=>            ] (00m:00s) 86 KB / ?? (65.52 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 344 KB / ?? (262.07 KB/s)
# conda-forge/noarch       [   <=>            ] (00m:00s) 86 KB / ?? (65.52 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 492 KB / ?? (333.47 KB/s)
# conda-forge/noarch       [    <=>           ] (00m:00s) 86 KB / ?? (65.52 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 492 KB / ?? (333.47 KB/s)
# conda-forge/noarch       [    <=>           ] (00m:00s) 96 KB / ?? (65.36 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 492 KB / ?? (333.47 KB/s)
# conda-forge/noarch       [    <=>           ] (00m:00s) 96 KB / ?? (65.36 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 492 KB / ?? (333.47 KB/s)
# conda-forge/noarch       [    <=>           ] (00m:00s) 96 KB / ?? (65.36 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 673 KB / ?? (412.48 KB/s)
# conda-forge/noarch       [     <=>          ] (00m:00s) 96 KB / ?? (65.36 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 673 KB / ?? (412.48 KB/s)
# conda-forge/noarch       [    <=>          ] (00m:00s) 147 KB / ?? (90.16 KB/s)
# conda-forge/linux-aarch6 [   <=>          ] (00m:00s) 673 KB / ?? (412.48 KB/s)
# conda-forge/noarch       [    <=>          ] (00m:01s) 147 KB / ?? (90.16 KB/s)
# conda-forge/linux-aarch6 [    <=>         ] (00m:00s) 673 KB / ?? (412.48 KB/s)
# conda-forge/noarch       [    <=>          ] (00m:01s) 147 KB / ?? (90.16 KB/s)
# conda-forge/linux-aarch6 [    <=>        ] (00m:00s) 1003 KB / ?? (562.75 KB/s)
# conda-forge/noarch       [     <=>         ] (00m:01s) 147 KB / ?? (90.16 KB/s)
# conda-forge/linux-aarch6 [    <=>        ] (00m:00s) 1003 KB / ?? (562.75 KB/s)
# conda-forge/noarch       [     <=>        ] (00m:01s) 201 KB / ?? (112.56 KB/s)
# conda-forge/linux-aarch6 [    <=>        ] (00m:00s) 1003 KB / ?? (562.75 KB/s)
# conda-forge/noarch       [     <=>        ] (00m:01s) 201 KB / ?? (112.56 KB/s)
# conda-forge/linux-aarch6 [     <=>       ] (00m:01s) 1003 KB / ?? (562.75 KB/s)
# conda-forge/noarch       [     <=>        ] (00m:01s) 201 KB / ?? (112.56 KB/s)
# conda-forge/linux-aarch6 [      <=>         ] (00m:01s) 1 MB / ?? (744.27 KB/s)
# conda-forge/noarch       [      <=>       ] (00m:01s) 201 KB / ?? (112.56 KB/s)
# conda-forge/linux-aarch6 [      <=>         ] (00m:01s) 1 MB / ?? (744.27 KB/s)
# conda-forge/noarch       [      <=>       ] (00m:01s) 352 KB / ?? (181.61 KB/s)
# conda-forge/linux-aarch6 [      <=>         ] (00m:01s) 1 MB / ?? (744.27 KB/s)
# conda-forge/noarch       [      <=>       ] (00m:01s) 352 KB / ?? (181.61 KB/s)
# conda-forge/linux-aarch6 [       <=>        ] (00m:01s) 1 MB / ?? (744.27 KB/s)
# conda-forge/noarch       [      <=>       ] (00m:01s) 352 KB / ?? (181.61 KB/s)
# conda-forge/linux-aarch6 [       <=>        ] (00m:01s) 2 MB / ?? (896.46 KB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 352 KB / ?? (181.61 KB/s)
# conda-forge/linux-aarch6 [       <=>        ] (00m:01s) 2 MB / ?? (896.46 KB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 568 KB / ?? (272.43 KB/s)
# conda-forge/linux-aarch6 [       <=>        ] (00m:01s) 2 MB / ?? (896.46 KB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 568 KB / ?? (272.43 KB/s)
# conda-forge/linux-aarch6 [        <=>       ] (00m:01s) 2 MB / ?? (896.46 KB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 568 KB / ?? (272.43 KB/s)
# conda-forge/linux-aarch6 [         <=>        ] (00m:01s) 2 MB / ?? (1.02 MB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 568 KB / ?? (272.43 KB/s)
# conda-forge/linux-aarch6 [         <=>        ] (00m:01s) 2 MB / ?? (1.02 MB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 892 KB / ?? (398.74 KB/s)
# conda-forge/linux-aarch6 [         <=>        ] (00m:01s) 2 MB / ?? (1.02 MB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 892 KB / ?? (398.74 KB/s)
# conda-forge/linux-aarch6 [          <=>       ] (00m:01s) 2 MB / ?? (1.02 MB/s)
# conda-forge/noarch       [       <=>      ] (00m:01s) 892 KB / ?? (398.74 KB/s)
# conda-forge/linux-aarch6 [          <=>       ] (00m:01s) 3 MB / ?? (1.15 MB/s)
# conda-forge/noarch       [        <=>     ] (00m:01s) 892 KB / ?? (398.74 KB/s)
# conda-forge/linux-aarch6 [          <=>       ] (00m:01s) 3 MB / ?? (1.15 MB/s)
# conda-forge/noarch       [         <=>      ] (00m:01s) 1 MB / ?? (592.60 KB/s)
# conda-forge/linux-aarch6 [          <=>       ] (00m:01s) 3 MB / ?? (1.15 MB/s)
# conda-forge/noarch       [         <=>      ] (00m:01s) 1 MB / ?? (592.60 KB/s)
# conda-forge/linux-aarch6 [           <=>      ] (00m:01s) 3 MB / ?? (1.15 MB/s)
# conda-forge/noarch       [         <=>      ] (00m:01s) 1 MB / ?? (592.60 KB/s)
# conda-forge/linux-aarch6 [           <=>      ] (00m:01s) 3 MB / ?? (1.25 MB/s)
# conda-forge/noarch       [          <=>     ] (00m:01s) 1 MB / ?? (592.60 KB/s)
# conda-forge/linux-aarch6 [           <=>      ] (00m:01s) 3 MB / ?? (1.25 MB/s)
# conda-forge/noarch       [          <=>     ] (00m:01s) 2 MB / ?? (728.25 KB/s)
# conda-forge/linux-aarch6 [           <=>      ] (00m:01s) 3 MB / ?? (1.25 MB/s)
# conda-forge/noarch       [          <=>     ] (00m:01s) 2 MB / ?? (728.25 KB/s)
# conda-forge/linux-aarch6 [            <=>     ] (00m:01s) 3 MB / ?? (1.25 MB/s)
# conda-forge/noarch       [          <=>     ] (00m:01s) 2 MB / ?? (728.25 KB/s)
# conda-forge/linux-aarch6 [            <=>     ] (00m:01s) 4 MB / ?? (1.33 MB/s)
# conda-forge/noarch       [           <=>    ] (00m:01s) 2 MB / ?? (728.25 KB/s)
# conda-forge/linux-aarch6 [            <=>     ] (00m:01s) 4 MB / ?? (1.33 MB/s)
# conda-forge/noarch       [           <=>    ] (00m:01s) 2 MB / ?? (789.32 KB/s)
# conda-forge/linux-aarch6 [            <=>     ] (00m:01s) 4 MB / ?? (1.33 MB/s)
# conda-forge/noarch       [           <=>    ] (00m:02s) 2 MB / ?? (789.32 KB/s)
# conda-forge/linux-aarch6 [             <=>    ] (00m:01s) 4 MB / ?? (1.33 MB/s)
# conda-forge/noarch       [           <=>    ] (00m:02s) 2 MB / ?? (789.32 KB/s)
# conda-forge/linux-aarch6 [             <=>    ] (00m:01s) 4 MB / ?? (1.41 MB/s)
# conda-forge/noarch       [            <=>   ] (00m:02s) 2 MB / ?? (789.32 KB/s)
# conda-forge/linux-aarch6 [             <=>    ] (00m:01s) 4 MB / ?? (1.41 MB/s)
# conda-forge/noarch       [            <=>   ] (00m:02s) 2 MB / ?? (808.36 KB/s)
# conda-forge/linux-aarch6 [             <=>    ] (00m:01s) 4 MB / ?? (1.41 MB/s)
# conda-forge/noarch       [             <=>  ] (00m:02s) 2 MB / ?? (808.36 KB/s)
# conda-forge/linux-aarch6 [             <=>    ] (00m:02s) 4 MB / ?? (1.41 MB/s)
# conda-forge/noarch       [             <=>  ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/linux-aarch6 [             <=>    ] (00m:02s) 4 MB / ?? (1.41 MB/s)
# conda-forge/noarch       [             <=>  ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/linux-aarch6 [              <=>   ] (00m:02s) 4 MB / ?? (1.41 MB/s)
# conda-forge/noarch       [             <=>  ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/linux-aarch6 [              <=>   ] (00m:02s) 4 MB / ?? (1.44 MB/s)
# conda-forge/noarch       [             <=>  ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/linux-aarch6 [              <=>   ] (00m:02s) Finalizing...
# conda-forge/noarch       [             <=>  ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/linux-aarch6 [              <=>   ] (00m:02s) Done
# conda-forge/linux-aarch6 [====================] (00m:02s) Done
# conda-forge/noarch       [             <=>  ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/noarch       [              <=> ] (00m:02s) 3 MB / ?? (867.14 KB/s)
# conda-forge/noarch       [              <=> ] (00m:02s) 3 MB / ?? (877.59 KB/s)
# conda-forge/noarch       [               <=>] (00m:02s) 3 MB / ?? (877.59 KB/s)
# conda-forge/noarch       [               <=>] (00m:02s) 3 MB / ?? (967.12 KB/s)
# conda-forge/noarch       [                <=] (00m:02s) 3 MB / ?? (967.12 KB/s)
# conda-forge/noarch       [               <=] (00m:02s) 3 MB / ?? (1003.02 KB/s)
# conda-forge/noarch       [                <] (00m:02s) 3 MB / ?? (1003.02 KB/s)
# conda-forge/noarch       [                 <] (00m:02s) 4 MB / ?? (993.11 KB/s)
# conda-forge/noarch       [                 <] (00m:03s) 4 MB / ?? (993.11 KB/s)
# conda-forge/noarch       [                    ] (00m:03s) 4 MB / ?? (1.11 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 4 MB / ?? (1.11 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 5 MB / ?? (1.21 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 5 MB / ?? (1.21 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 5 MB / ?? (1.27 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 5 MB / ?? (1.27 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 6 MB / ?? (1.34 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 6 MB / ?? (1.34 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 6 MB / ?? (1.39 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 6 MB / ?? (1.39 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 7 MB / ?? (1.44 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 7 MB / ?? (1.44 MB/s)
# conda-forge/noarch       [                    ] (00m:03s) 7 MB / ?? (1.48 MB/s)
# conda-forge/noarch       [                    ] (00m:04s) 7 MB / ?? (1.48 MB/s)
# conda-forge/noarch       [                    ] (00m:04s) 7 MB / ?? (1.53 MB/s)
# conda-forge/noarch       [                    ] (00m:04s) Finalizing...
# conda-forge/noarch       [                    ] (00m:04s) Done
# conda-forge/noarch       [====================] (00m:04s) Done
#
# Pinned packages:
#   - python 3.9.*
#   - python 3.9.10
#
#
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - pandarallel
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package        Version  Build         Channel                 Size
# ──────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────
#
#   + pandarallel    1.6.1  pyhd8ed1ab_0  conda-forge/noarch     16 KB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 16 KB
#
# ──────────────────────────────────────────────────────────────────────
#
# Downloading  [=========================================] (00m:00s)   27.49 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished pandarallel                          (00m:00s)              16 KB     27 KB/s
# Downloading  [=========================================] (00m:00s)   27.49 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)   27.49 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)   27.49 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)   27.49 KB/s
# Extracting   [=========================================] (00m:00s)        1 / 1
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import requests
import pandas as pd
import json
import numpy as np
from bs4 import BeautifulSoup
from tqdm.auto import tqdm
from time import sleep
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True, nb_workers=16)
tqdm.pandas()
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
BASE_URL = 'https://musicbrainz.org'
SEARCH_URL = f'{BASE_URL}/search'

YEAR = 2000
RELEASES_QUERY = f'firstreleasedate:{YEAR} AND type:(-Compilation -DJ-mix -Soundtrack -Remix -Live -Spokenword)'
ERROR = 'We could not fetch the document from the search server'

# %%
def get_rows(page):
    for i in range(5):
        params = {
            'query': RELEASES_QUERY,
            'type': 'release_group',
            'limit': '100',
            'method': 'advanced',
            'page': page,
        }
        resp = requests.get(SEARCH_URL, params)
        rows = BeautifulSoup(resp.text).find('tbody')
        
        if not rows:
            if ERROR in resp.text:
                print(f'error, retrying ({i})')
                sleep(1)
                continue

            return None

        return rows.find_all('tr')

# %%
def row2release(row):
    release, artist, rtype = row.find_all('td')
    return {
        'release_type': rtype.text,
        'release_name': release.text,
        'release_link': release.find('a')['href'],
        'artist_name': artist.text,
        'artist_link': artist.find('a')['href'],
    }

# %%
pages = {}

# %%
for page in tqdm(range(1, 100000)):
    if page in pages:
        continue

    rows = get_rows(page)
    if not rows:
        break

    pages[page] = [row2release(r) for r in rows]
# Out:
#   0%|          | 0/99999 [00:00<?, ?it/s]
# error, retrying (0)
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/static/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/static/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/static/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/static/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/static/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/static/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/static/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/static/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/static/images/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="/static/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/static/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/static/images/favicons/site.webmanifest" rel="manifest"/><link color="#bb4890" href="/static/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/><link href="/favicon.ico" rel="shortcut icon"/><meta content="#f1f1f1" name="msapplication-TileColor"/><meta content="/static/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><title>Search Results - MusicBrainz</title><link href="https://staticbrainz.org/MB/common-77825d4.css" rel="stylesheet" type="text/css"/><link href="https://staticbrainz.org/MB/icons-7f3dfb2.css" rel="stylesheet" type="text/css"/><link href="/static/search_plugins/opensearch/musicbrainz_artist.xml" rel="search" title="MusicBrainz: Artist" type="application/opensearchdescription+xml"/><link href="/static/search_plugins/opensearch/musicbrainz_label.xml" rel="search" title="MusicBrainz: Label" type="application/opensearchdescription+xml"/><link href="/static/search_plugins/opensearch/musicbrainz_release.xml" rel="search" title="MusicBrainz: Release" type="application/opensearchdescription+xml"/><link href="/static/search_plugins/opensearch/musicbrainz_track.xml" rel="search" title="MusicBrainz: Track" type="application/opensearchdescription+xml"/><noscript><link href="https://staticbrainz.org/MB/noscript-dfb70de.css" rel="stylesheet" type="text/css"/></noscript><script>Object.defineProperty(window,"__MB__",{value:Object.freeze({"DBDefs":Object.freeze({"DB_STAGING_TESTING_FEATURES":false,"DEVELOPMENT_SERVER":false,"CRITIQUEBRAINZ_SERVER":"https://critiquebrainz.org","GIT_BRANCH":"production","GIT_SHA":"f86dae5998","MAPBOX_ACCESS_TOKEN":"pk.eyJ1IjoibXVzaWNicmFpbnoiLCJhIjoiVmUzVE5ETSJ9.ZAiQ0I_Qf0i8FySu5uCAUQ","MAPBOX_MAP_ID":"mapbox/streets-v11","SENTRY_DSN_PUBLIC":"https://ef4496db86b94442a35f3fe368287a33@sentry.metabrainz.org/12","STATIC_RESOURCES_LOCATION":"https://staticbrainz.org/MB","WEB_SERVER":"musicbrainz.org","WIKITRANS_SERVER":"wiki.musicbrainz.org","MB_LANGUAGES":["de","fr","it","nl","en"]}),"$c":Object.freeze({"action":{"name":"search"},"relative_uri":"/search?query=firstreleasedate%3A2000+AND+type%3A(-Compilation+-DJ-mix+-Soundtrack+-Remix+-Live+-Spokenword)&type=release_group&limit=100&method=advanced&page=337","req":{"uri":"https://musicbrainz.org/search?query=firstreleasedate%3A2000+AND+type%3A(-Compilation+-DJ-mix+-Soundtrack+-Remix+-Live+-Spokenword)&type=release_group&limit=100&method=advanced&page=337"},"session":{},"stash":{"current_language":"en"},"user":null})})})</script><script src="https://staticbrainz.org/MB/runtime-9a3f8db.js"></script><script src="https://staticbrainz.org/MB/common-chunks-4b1c23b.js"></script><script sr ...

# %%
df = pd.concat(pd.DataFrame(p) for p in pages.values())
df.head()
# Out:
#   release_type        release_name  \
# 0        Album      Lenka Dusilová
# 1        Album  Ça parle au diable
# 2        Album   Afterlife Kingdom
# 3        Album         Call Me Al!
# 4        Album   Nowhere Near Here
#
#                                         release_link        artist_name  \
# 0  /release-group/2a23335a-5590-30c3-b25c-884cabe...     Lenka Dusilová
# 1  /release-group/71058210-8408-3aed-8878-3ad2e4a...          Mes Aïeux
# 2  /release-group/3d648595-b55e-3968-a333-390d257...  Satanic Slaughter
# 3  /release-group/53dd9a96-e8ea-3200-abee-8911b55...        Alain Caron
# 4  /release-group/a8ce8cf1-3def-30af-b387-65acd97...       Alex Woodard
#
#                                     artist_link
# 0  /artist/4d60cb9c-81e2-4ae2-9976-b640b545a303
# 1  /artist/a320d461-a689-4946-a686-70a6eaebdffb
# 2  /artist/1fd06f01-fb68-43ee-a392-af7336250df1
# 3  /artist/f95594fd-8ba6-4540-8854-7c149153a891
# 4  /artist/265b1f16-f15c-484f-a6b7-2be20dcf6a9e

# %%
len(df)
# Out:
# 33541

# %%
df.to_pickle(f'{YEAR}/releases.pickle')

# %%
def get_links(artist_link):
    for i in range(5):
        resp = requests.get(f'{BASE_URL}{artist_link}')
        links = BeautifulSoup(resp.text).find(class_='external_links')
        if not links:
            if resp.status_code == 200:
                return {}
            
            print(f'{BASE_URL}{artist_link}')
            print(f'error, retrying ({i})')
            sleep(1)
            continue

        links = {
            li['class'][0].replace('-favicon', ''): li.find('a')['href']
            for li in links.find_all('li')[:-1]
        }
        return links

# %%
df['links'] = df['artist_link'].parallel_apply(get_links)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1678), Label(value='0 / 1678'))), …

# %%
df = pd.concat([
    df.drop(['links'], axis=1).reset_index(drop=True),
    pd.json_normalize(df['links']).reset_index(drop=True)
], axis=1)

# %%
df.to_pickle(f'{YEAR}/releases.pickle')

# %%
list(df.columns)
# Out:
# ['release_type',
#  'release_name',
#  'release_link',
#  'artist_name',
#  'artist_link',
#  'discogs',
#  'wikipedia',
#  'viaf',
#  'wikidata',
#  'home',
#  'itunes',
#  'deezer',
#  'spotify',
#  'allmusic',
#  'metalarchives',
#  'songkick',
#  'bnfcatalogue',
#  'dnb',
#  'instagram',
#  'youtube',
#  'facebook',
#  'twitter',
#  'bandsintown',
#  'amazon',
#  'genius',
#  'imdb',
#  'lastfm',
#  'rateyourmusic',
#  'reverbnation',
#  'secondhandsongs',
#  'setlistfm',
#  'whosampled',
#  'worldcat',
#  'loc',
#  'myspace',
#  'generasia',
#  'vgmdb',
#  'musiksammler',
#  'applemusic',
#  'bandcamp',
#  'vimeo',
#  'amazonmusic',
#  'mora',
#  'no',
#  'utanet',
#  'encyclopedisque',
#  'youtubemusic',
#  'weibo',
#  'snac',
#  'imslp',
#  'openlibrary',
#  'trove',
#  'ibdb',
#  'classicalarchives',
#  'soundcloud',
#  'muzikum',
#  'blog',
#  'rockcomar',
#  'progarchives',
#  'fortyfiveworlds',
#  'animenewsnetwork',
#  'muziekweb',
#  'cinii',
#  'musicapopularcl',
#  'anisongeneration',
#  'fortyfivecat',
#  'imvdb',
#  'tidal',
#  'baidu',
#  'ocremix',
#  'musixmatch',
#  'napster',
#  'qobuz',
#  'spiritofrock',
#  'ircam',
#  'quebecinfomusique',
#  'beatport',
#  'psydb',
#  'cdjapan',
#  'utaitedb',
#  'recochoku',
#  'residentadvisor',
#  'overture',
#  'mixcloud',
#  'junodownload',
#  'livefans',
#  'bookbrainz',
#  'lieder',
#  'utamap',
#  'vk',
#  'twitch',
#  'pinterest',
#  'spiritofmetal',
#  'finnmusic',
#  'rolldabeats',
#  'vkdb',
#  'dahr',
#  'jlyric',
#  'tower',
#  'dailymotion',
#  'archive',
#  'jazzmusicarchives',
#  'tiktok',
#  'cpdl',
#  'linkedin',
#  'utaten',
#  'directlyrics',
#  'bigcartel',
#  'patreon',
#  'vocadb',
#  'ric',
#  'dogmazic',
#  'videogamin',
#  'castalbums',
#  'dhhu',
#  'operabase',
#  'mainlynorfolk',
#  'thesession',
#  'piosenki',
#  'wikisource',
#  'songfacts',
#  'traxsource',
#  'rockipedia',
#  'kickstarter',
#  'gutenberg',
#  'theatricalia']

# %%
pd.set_option('display.max_columns', 130)
df.describe()
# Out:
#        release_type release_name  \
# count         33541        33541
# unique           27        24057
# top           Album   [untitled]
# freq          21526           23
#
#                                              release_link      artist_name  \
# count                                               33541            33541
# unique                                              24970            20627
# top     /release-group/3ef443d3-0e58-4bdc-9804-e7c6b97...  Various Artists
# freq                                                    4              731
#
#                                          artist_link  \
# count                                          33541
# unique                                         19614
# top     /artist/89ad4ac3-39f7-470e-963a-56509c546377
# freq                                             731
#
#                                    discogs  \
# count                                29519
# unique                               16774
# top     https://www.discogs.com/artist/194
# freq                                   731
#
#                                            wikipedia  \
# count                                           4841
# unique                                          2851
# top     //en.wikipedia.org/wiki/Ludwig_van_Beethoven
# freq                                              60
#
#                                    viaf                          wikidata  \
# count                              9890                             19754
# unique                             4833                             10241
# top     https://viaf.org/viaf/12304462/  //www.wikidata.org/wiki/Q3108914
# freq                                251                               731
#
#                                   home  \
# count                            14767
# unique                            8293
# top     http://www.tonyoconnor.com.au/
# freq                                22
#
#                                             itunes  \
# count                                         5244
# unique                                        2187
# top     https://itunes.apple.com/us/artist/id11862
# freq                                           251
#
#                                     deezer  \
# count                                 6745
# unique                                2654
# top     https://www.deezer.com/artist/5080
# freq                                   731
#
#                                                   spotify  \
# count                                                9634
# unique                                               4085
# top     https://open.spotify.com/artist/0LyfQWJT6nXafL...
# freq                                                  731
#
#                                             allmusic  \
# count                                          12567
# unique                                          6330
# top     https://www.allmusic.com/artist/mn0000075140
# freq                                             251
#
#                                             metalarchives  \
# count                                                1692
# unique                                               1111
# top     https://www.metal-archives.com/bands/Nightwish/39
# freq                                                    9
#
#                                        songkick  \
# count                                      6491
# unique                                     3000
# top     https://www.songkick.com/artists/556956
# freq                                        251
#
#                                            bnfcatalogue  \
# count                                              5326
# unique                                             2369
# top     https://catalogue.bnf.fr/ark:/12148/cb118897907
# freq                                                251
#
#                                    dnb  \
# count                             5873
# unique                            2611
# top     http://d-nb.info/gnd/11850553X
# freq                               251
#
#                                       instagram  \
# count                                      2595
# unique                                     1250
# top     https://www.instagram.com/speedguru666/
# freq                                         15
#
#                                                   youtube  \
# count                                                4577
# unique                                               2247
# top     //www.youtube.com/channel/UCB4ceM1ygPEMWu3_-2-...
# freq                                                   15
#
#                                                  facebook  \
# count                                                7934
# unique                                               4165
# top     https://www.facebook.com/pages/Beethoven/11066...
# freq                                                   60
#
#                                twitter                        bandsintown  \
# count                             5192                               1242
# unique                            2583                                542
# top     https://twitter.com/limpbizkit  https://www.bandsintown.com/a/292
# freq                                15                                 15
#
#                                                    amazon  \
# count                                                1359
# unique                                                308
# top     //www.amazon.com/-/e/B0017PCMX0?tag=musicbrain...
# freq                                                  251
#
#                                                   genius  \
# count                                               2321
# unique                                               890
# top     https://genius.com/artists/Johann-sebastian-bach
# freq                                                 251
#
#                                         imdb  \
# count                                   5960
# unique                                  2551
# top     https://www.imdb.com/name/nm0001925/
# freq                                     251
#
#                                            lastfm  \
# count                                        7997
# unique                                       3364
# top     https://www.last.fm/music/Various+Artists
# freq                                          731
#
#                                             rateyourmusic  \
# count                                               11735
# unique                                               5876
# top     https://rateyourmusic.com/artist/johann_sebast...
# freq                                                  251
#
#                                  reverbnation  \
# count                                     305
# unique                                    183
# top     https://www.reverbnation.com/delasoul
# freq                                        7
#
#                                 secondhandsongs  \
# count                                      2789
# unique                                     1005
# top     https://secondhandsongs.com/artist/4192
# freq                                        251
#
#                                                 setlistfm  \
# count                                                2214
# unique                                                941
# top     https://www.setlist.fm/setlists/johann-sebasti...
# freq                                                  251
#
#                                                whosampled  \
# count                                                1714
# unique                                                547
# top     https://www.whosampled.com/Johann-Sebastian-Bach/
# freq                                                  251
#
#                                                  worldcat  \
# count                                                6380
# unique                                               2881
# top     https://www.worldcat.org/identities/lccn-n7902...
# freq                                                  251
#
#                                                    loc  \
# count                                             5755
# unique                                            2608
# top     https://id.loc.gov/authorities/names/n79021425
# freq                                               251
#
#                                myspace  \
# count                             7843
# unique                            4349
# top     https://myspace.com/limpbizkit
# freq                                15
#
#                                             generasia  \
# count                                             322
# unique                                            116
# top     https://www.generasia.com/wiki/Himuro_Kyosuke
# freq                                               12
#
#                                 vgmdb  \
# count                            1457
# unique                            268
# top     https://vgmdb.net/artist/1718
# freq                              251
#
#                                              musiksammler  \
# count                                                2857
# unique                                               1161
# top     https://www.musik-sammler.de/artist/johann-seb...
# freq                                                  251
#
#                                      applemusic  \
# count                                      1243
# unique                                      558
# top     https://music.apple.com/us/artist/12374
# freq                                         65
#
#                                bandcamp                              vimeo  \
# count                              2046                                126
# unique                             1144                                 61
# top     //kawabata-makoto.bandcamp.com/  https://vimeo.com/thedandywarhols
# freq                                 15                                  8
#
#                                         amazonmusic  \
# count                                          1256
# unique                                          190
# top     https://music.amazon.com/artists/B000QJO93Y
# freq                                            731
#
#                                  mora  \
# count                             100
# unique                             31
# top     https://mora.jp/artist/11490/
# freq                                7
#
#                                                     no  \
# count                                             2601
# unique                                             756
# top     https://soundtrackcollector.com/composer/4977/
# freq                                               251
#
#                                       utanet  \
# count                                     31
# unique                                     9
# top     https://www.uta-net.com/artist/1822/
# freq                                       7
#
#                                         encyclopedisque  \
# count                                                86
# unique                                               43
# top     http://www.encyclopedisque.fr/artiste/2361.html
# freq                                                  6
#
#                                              youtubemusic  \
# count                                                  97
# unique                                                 52
# top     https://music.youtube.com/channel/UCaqljTNgQHS...
# freq                                                    6
#
#                                            weibo  \
# count                                         57
# unique                                        27
# top     https://www.weibo.com/linkinparkofficial
# freq                                           9
#
#                                                   snac  \
# count                                             2218
# unique                                             723
# top     http://snaccooperative.org/ark:/99166/w63x84mt
# freq                                               251
#
#                                                     imslp  \
# count                                                1343
# unique                                                261
# top     https://imslp.org/wiki/Category:Bach,_Johann_S...
# freq                                                  251
#
#                                     openlibrary  \
# count                                      1595
# unique                                      347
# top     https://openlibrary.org/works/OL443516A
# freq                                        251
#
#                                       trove  \
# count                                  1706
# unique                                  393
# top     https://nla.gov.au/nla.party-789063
# freq                                    251
#
#                                         ibdb  \
# count                                   1065
# unique                                   177
# top     https://ibdb.com/person.php?id=10027
# freq                                     251
#
#                                         classicalarchives  \
# count                                                 285
# unique                                                 41
# top     https://www.classicalarchives.com/composer/330...
# freq                                                   39
#
#                                       soundcloud  \
# count                                       2600
# unique                                      1184
# top     https://soundcloud.com/makoto-kawabata-1
# freq                                          15
#
#                                                   muzikum  \
# count                                                2573
# unique                                               1103
# top     http://muzikum.eu/en/122-6434/ludwig-van-beeth...
# freq                                                   60
#
#                                     blog  \
# count                                732
# unique                               328
# top     http://speedguru.blog45.fc2.com/
# freq                                  15
#
#                                          rockcomar  \
# count                                           72
# unique                                          54
# top     http://rock.com.ar/artistas/los-violadores
# freq                                             3
#
#                                            progarchives  \
# count                                               198
# unique                                              103
# top     https://www.progarchives.com/artist.asp?id=2407
# freq                                                 12
#
#                                           fortyfiveworlds  \
# count                                                 169
# unique                                                 49
# top     http://www.45worlds.com/classical/composer/bee...
# freq                                                   60
#
#                                          animenewsnetwork  \
# count                                                 242
# unique                                                 44
# top     https://www.animenewsnetwork.com/encyclopedia/...
# freq                                                   65
#
#                                                 muziekweb  \
# count                                                 583
# unique                                                168
# top     https://www.muziekweb.nl/Link/M00000235994/CLA...
# freq                                                   60
#
#                                               cinii  \
# count                                            69
# unique                                           18
# top     https://ci.nii.ac.jp/author/DA02483346?l=en
# freq                                             20
#
#                                           musicapopularcl  \
# count                                                  14
# unique                                                 11
# top     http://www.musicapopular.cl/artista/francesca-...
# freq                                                    2
#
#                                  anisongeneration  \
# count                                         180
# unique                                         64
# top     http://anison.info/data/person/35211.html
# freq                                           10
#
#                                    fortyfivecat  \
# count                                       791
# unique                                      318
# top     http://www.45cat.com/artist/limp-bizkit
# freq                                         15
#
#                                   imvdb                       tidal  \
# count                              1263                        1481
# unique                              465                         550
# top     https://imvdb.com/n/limp-bizkit  //tidal.com/artist/3901460
# freq                                 15                          19
#
#                                            baidu  \
# count                                         13
# unique                                         8
# top     https://baike.baidu.com/item/John%20zorn
# freq                                           5
#
#                                                   ocremix  \
# count                                                  24
# unique                                                 15
# top     https://ocremix.org/artist/10319/the-cynic-pro...
# freq                                                    3
#
#                                       musixmatch  \
# count                                        510
# unique                                       178
# top     https://www.musixmatch.com/artist/Prince
# freq                                          12
#
#                                           napster  \
# count                                         444
# unique                                        155
# top     https://us.napster.com/artist/the-beatles
# freq                                           12
#
#                                                     qobuz  \
# count                                                 150
# unique                                                 59
# top     https://www.qobuz.com/gb-en/interpreter/the-be...
# freq                                                   12
#
#                                          spiritofrock  \
# count                                             210
# unique                                             79
# top     https://www.spirit-of-rock.com/en/band/Prince
# freq                                               12
#
#                                               ircam  \
# count                                            16
# unique                                            9
# top     http://brahms.ircam.fr/krzysztof-penderecki
# freq                                              5
#
#                                         quebecinfomusique  \
# count                                                  36
# unique                                                 18
# top     http://www.qim.com/artistes/biographie.asp?art...
# freq                                                    5
#
#                                             beatport  \
# count                                            581
# unique                                           234
# top     https://www.beatport.com/artist/prince/73994
# freq                                              12
#
#                                                     psydb  \
# count                                                  23
# unique                                                 13
# top     http://www.psydb.net/artists/i/infected-mushro...
# freq                                                    7
#
#                                        cdjapan                       utaitedb  \
# count                                      180                             24
# unique                                      68                             10
# top     https://www.cdjapan.co.jp/person/96621  https://utaitedb.net/Ar/20957
# freq                                         9                              5
#
#                                       recochoku          residentadvisor  \
# count                                        59                      239
# unique                                       18                      100
# top     https://recochoku.jp/artist/2000000011/  https://ra.co/dj/lusine
# freq                                          7                        7
#
#                                                  overture  \
# count                                                 251
# unique                                                  1
# top     https://overture.doremus.org/artist/269cec9d-5...
# freq                                                  251
#
#                                      mixcloud  \
# count                                      40
# unique                                     18
# top     http://www.mixcloud.com/soniqueclarke
# freq                                        5
#
#                                              junodownload  \
# count                                                 399
# unique                                                141
# top     https://www.junodownload.com/artists/Prince/re...
# freq                                                   12
#
#                                     livefans  \
# count                                    236
# unique                                    80
# top     https://www.livefans.jp/artists/2099
# freq                                      11
#
#                                                bookbrainz  \
# count                                                  30
# unique                                                 13
# top     https://bookbrainz.org/author/e53b85da-6147-46...
# freq                                                    8
#
#                                                    lieder  \
# count                                                  15
# unique                                                  3
# top     http://www.lieder.net/lieder/get_settings.html...
# freq                                                    9
#
#                                                    utamap  \
# count                                                  38
# unique                                                 11
# top     http://www.utamap.com/searchartist.php?artisti...
# freq                                                    7
#
#                                vk                                  twitch  \
# count                         272                                      39
# unique                        121                                       9
# top     https://vk.com/limpbizkit  https://www.twitch.tv/deftonesofficial
# freq                           15                                       7
#
#                                   pinterest  \
# count                                    54
# unique                                   18
# top     https://www.pinterest.com/xtina866/
# freq                                     10
#
#                                             spiritofmetal  \
# count                                                 345
# unique                                                145
# top     http://www.spirit-of-metal.com/groupe-groupe-L...
# freq                                                   15
#
#                                                 finnmusic  \
# count                                                  24
# unique                                                 11
# top     http://www.finnmusic.net/main.php?61505e5c0155...
# freq                                                    4
#
#                                       rolldabeats  \
# count                                         181
# unique                                         68
# top     http://www.rolldabeats.com/artist/digital
# freq                                           12
#
#                                      vkdb  \
# count                                  51
# unique                                 23
# top     https://www.vkdb.jp/LUNA+SEA.html
# freq                                    5
#
#                                                      dahr  \
# count                                                   8
# unique                                                  2
# top     http://adp.library.ucsb.edu/index.php/talent/d...
# freq                                                    6
#
#                                     jlyric                           tower  \
# count                                   42                              29
# unique                                  14                              12
# top     http://j-lyric.net/artist/a00055b/  https://tower.jp/artist/365201
# freq                                     5                               6
#
#                                           dailymotion  \
# count                                              35
# unique                                             13
# top     https://www.dailymotion.com/christinaaguilera
# freq                                               10
#
#                                 archive  \
# count                                36
# unique                               19
# top     //archive.org/details/RyanAdams
# freq                                  4
#
#                                         jazzmusicarchives  \
# count                                                  42
# unique                                                 24
# top     https://www.jazzmusicarchives.com/artist/enric...
# freq                                                    4
#
#                           tiktok  \
# count                         27
# unique                         9
# top     https://tiktok.com/@moby
# freq                           6
#
#                                                      cpdl  \
# count                                                   2
# unique                                                  1
# top     http://cpdl.org/wiki/index.php/Charles_Hubert_...
# freq                                                    2
#
#                                      linkedin  \
# count                                      26
# unique                                     19
# top     https://de.linkedin.com/in/ameliacuni
# freq                                        4
#
#                                                    utaten  \
# count                                                   7
# unique                                                  2
# top     https://utaten.com/artist/%E5%80%89%E6%A9%8B%E...
# freq                                                    4
#
#                                              directlyrics  \
# count                                                  98
# unique                                                 25
# top     http://www.directlyrics.com/christina-aguilera...
# freq                                                   10
#
#                                      bigcartel  \
# count                                       15
# unique                                       6
# top     https://suicidecommando.bigcartel.com/
# freq                                         3
#
#                                     patreon                      vocadb  \
# count                                    13                           2
# unique                                    9                           1
# top     https://www.patreon.com/montyharper  https://vocadb.net/Ar/5841
# freq                                      2                           2
#
#                                            ric  \
# count                                        1
# unique                                       1
# top     http://www.rockinchina.com/w/New_Pants
# freq                                         1
#
#                                                  dogmazic  \
# count                                                   5
# unique                                                  3
# top     http://play.dogmazic.net/index.php#artists.php...
# freq                                                    2
#
#                                         videogamin  \
# count                                            3
# unique                                           2
# top     http://videogam.in/people/Yasunori_Mitsuda
# freq                                             2
#
#                                              castalbums  \
# count                                                33
# unique                                                8
# top     http://castalbums.org/people/The-Beatles/118334
# freq                                                 12
#
#                                                   dhhu  \
# count                                                1
# unique                                               1
# top     http://dhhu.dk/wiki/index.php?title=Kongehuset
# freq                                                 1
#
#                                  operabase  \
# count                                    5
# unique                                   4
# top     https://operabase.com/artists/1890
# freq                                     2
#
#                                             mainlynorfolk  \
# count                                                   1
# unique                                                  1
# top     https://mainlynorfolk.info/folk/records/blazin...
# freq                                                    1
#
#                                             thesession  \
# count                                                3
# unique                                               3
# top     https://thesession.org/recordings/artists/1381
# freq                                                 1
#
#                                                  piosenki  \
# count                                                   1
# unique                                                  1
# top     https://bibliotekapiosenki.pl/zespoly/Cracow_K...
# freq                                                    1
#
#                                                wikisource  \
# count                                                   6
# unique                                                  2
# top     https://en.wikisource.org/wiki/Author:Billy_Bragg
# freq                                                    3
#
#                                                 songfacts  \
# count                                                   2
# unique                                                  1
# top     http://www.songfacts.com/facts-suicidal_tenden...
# freq                                                    2
#
#                                      traxsource  \
# count                                         7
# unique                                        4
# top     https://www.traxsource.com/artist/36837
# freq                                          2
#
#                                             rockipedia  \
# count                                                9
# unique                                               4
# top     https://www.rockipedia.no/artister/a-ha-15645/
# freq                                                 5
#
#                                               kickstarter  \
# count                                                   2
# unique                                                  1
# top     https://www.kickstarter.com/profile/rockyvotolato
# freq                                                    2
#
#                                          gutenberg  \
# count                                            4
# unique                                           2
# top     http://www.gutenberg.org/author/Ian,+Janis
# freq                                             2
#
#                                theatricalia
# count                                     2
# unique                                    1
# top     http://theatricalia.com/person/26hm
# freq                                      2

# %%
df[(df.spotify.notna()|df.youtube.notna()|df.bandcamp.notna()|df.lastfm.notna()|df.wikipedia.notna())]
# Out:
#       release_type        release_name  \
# 0            Album      Lenka Dusilová
# 1            Album  Ça parle au diable
# 3            Album         Call Me Al!
# 4            Album   Nowhere Near Here
# 6            Album             Paivepo
# ...            ...                 ...
# 33536       Single     Stiff Upper Lip
# 33537        Album  California Dreamin
# 33538           EP     Stiff Upper Lip
# 33539       Single     Satellite Blues
# 33540        Album   Africa N’da Blues
#
#                                             release_link  \
# 0      /release-group/2a23335a-5590-30c3-b25c-884cabe...
# 1      /release-group/71058210-8408-3aed-8878-3ad2e4a...
# 3      /release-group/53dd9a96-e8ea-3200-abee-8911b55...
# 4      /release-group/a8ce8cf1-3def-30af-b387-65acd97...
# 6      /release-group/0e4b08cd-ae95-3922-802f-c49fa8d...
# ...                                                  ...
# 33536  /release-group/5259dd42-3636-31c5-9311-d011b25...
# 33537  /release-group/ed938e59-3c6c-4d64-8df2-55984bd...
# 33538  /release-group/61f736e8-b7dd-48c6-b164-1d2f91c...
# 33539  /release-group/9d7d4079-3c30-3352-ba6e-2bb479b...
# 33540  /release-group/1a3a5e70-dfae-4c45-9708-a42722a...
#
#                         artist_name  \
# 0                    Lenka Dusilová
# 1                         Mes Aïeux
# 3                       Alain Caron
# 4                      Alex Woodard
# 6                   Oliver Mtukudzi
# ...                             ...
# 33536                         AC/DC
# 33537         The Mamas & the Papas
# 33538                         AC/DC
# 33539                         AC/DC
# 33540  Kahil El’Zabar’s Ritual Trio
#
#                                         artist_link  \
# 0      /artist/4d60cb9c-81e2-4ae2-9976-b640b545a303
# 1      /artist/a320d461-a689-4946-a686-70a6eaebdffb
# 3      /artist/f95594fd-8ba6-4540-8854-7c149153a891
# 4      /artist/265b1f16-f15c-484f-a6b7-2be20dcf6a9e
# 6      /artist/566fb0fe-cf3a-48d1-a4ea-e9e6aaf7236e
# ...                                             ...
# 33536  /artist/66c662b6-6e2f-4930-8610-912e24c63ed1
# 33537  /artist/ff294730-0315-440d-a543-54005779c15b
# 33538  /artist/66c662b6-6e2f-4930-8610-912e24c63ed1
# 33539  /artist/66c662b6-6e2f-4930-8610-912e24c63ed1
# 33540  /artist/caa2c74d-55d8-4c54-bcbd-85c9fd7b575c
#
#                                       discogs  \
# 0       https://www.discogs.com/artist/557781
# 1      https://www.discogs.com/artist/2209784
# 3       https://www.discogs.com/artist/267096
# 4       https://www.discogs.com/artist/732422
# 6       https://www.discogs.com/artist/680928
# ...                                       ...
# 33536    https://www.discogs.com/artist/84752
# 33537   https://www.discogs.com/artist/230387
# 33538    https://www.discogs.com/artist/84752
# 33539    https://www.discogs.com/artist/84752
# 33540   https://www.discogs.com/artist/322784
#
#                                            wikipedia  \
# 0        //en.wikipedia.org/wiki/Lenka_Dusilov%C3%A1
# 1             //en.wikipedia.org/wiki/Mes_A%C3%AFeux
# 3      //en.wikipedia.org/wiki/Alain_Caron_(bassist)
# 4                                                NaN
# 6            //en.wikipedia.org/wiki/Oliver_Mtukudzi
# ...                                              ...
# 33536                                            NaN
# 33537                                            NaN
# 33538                                            NaN
# 33539                                            NaN
# 33540                                            NaN
#
#                                    viaf                          wikidata  \
# 0       https://viaf.org/viaf/85482923/  //www.wikidata.org/wiki/Q3490011
# 1                                   NaN  //www.wikidata.org/wiki/Q2567516
# 3       https://viaf.org/viaf/37110944/   //www.wikidata.org/wiki/Q714021
# 4                                   NaN                               NaN
# 6      https://viaf.org/viaf/261832847/   //www.wikidata.org/wiki/Q983221
# ...                                 ...                               ...
# 33536  https://viaf.org/viaf/144189738/    //www.wikidata.org/wiki/Q27593
# 33537  https://viaf.org/viaf/229179345/   //www.wikidata.org/wiki/Q211277
# 33538  https://viaf.org/viaf/144189738/    //www.wikidata.org/wiki/Q27593
# 33539  https://viaf.org/viaf/144189738/    //www.wikidata.org/wiki/Q27593
# 33540                               NaN                               NaN
#
#                                       home  \
# 0                                      NaN
# 1                   http://mesaieux.qc.ca/
# 3      https://www.alaincaronofficial.com/
# 4                                      NaN
# 6                                      NaN
# ...                                    ...
# 33536                 http://www.acdc.com/
# 33537                                  NaN
# 33538                 http://www.acdc.com/
# 33539                 http://www.acdc.com/
# 33540                                  NaN
#
#                                                itunes  \
# 0                                                 NaN
# 1      https://itunes.apple.com/ca/artist/id139482404
# 3                                                 NaN
# 4                                                 NaN
# 6          https://itunes.apple.com/artist/id56551652
# ...                                               ...
# 33536    https://itunes.apple.com/us/artist/id5040714
# 33537                                             NaN
# 33538    https://itunes.apple.com/us/artist/id5040714
# 33539    https://itunes.apple.com/us/artist/id5040714
# 33540                                             NaN
#
#                                       deezer  \
# 0                                        NaN
# 1        https://www.deezer.com/artist/13597
# 3                                        NaN
# 4                                        NaN
# 6                                        NaN
# ...                                      ...
# 33536      https://www.deezer.com/artist/115
# 33537      https://www.deezer.com/artist/539
# 33538      https://www.deezer.com/artist/115
# 33539      https://www.deezer.com/artist/115
# 33540  https://www.deezer.com/artist/1269398
#
#                                                  spotify  \
# 0                                                    NaN
# 1      https://open.spotify.com/artist/2heZLxgJjmZjVP...
# 3                                                    NaN
# 4                                                    NaN
# 6      https://open.spotify.com/artist/0HC2dfJHpORLT2...
# ...                                                  ...
# 33536  https://open.spotify.com/artist/711MCceyCBcFnz...
# 33537  https://open.spotify.com/artist/1bs7HoMkSyQwco...
# 33538  https://open.spotify.com/artist/711MCceyCBcFnz...
# 33539  https://open.spotify.com/artist/711MCceyCBcFnz...
# 33540  https://open.spotify.com/artist/0AuhzXNEVx1LGy...
#
#                                            allmusic metalarchives  \
# 0                                               NaN           NaN
# 1                                               NaN           NaN
# 3                                               NaN           NaN
# 4                                               NaN           NaN
# 6      https://www.allmusic.com/artist/mn0000471887           NaN
# ...                                             ...           ...
# 33536  https://www.allmusic.com/artist/mn0000574772           NaN
# 33537  https://www.allmusic.com/artist/mn0000059293           NaN
# 33538  https://www.allmusic.com/artist/mn0000574772           NaN
# 33539  https://www.allmusic.com/artist/mn0000574772           NaN
# 33540  https://www.allmusic.com/artist/mn0000281911           NaN
#
#                                                 songkick  \
# 0                                                    NaN
# 1                                                    NaN
# 3                https://www.songkick.com/artists/172864
# 4                                                    NaN
# 6      https://www.songkick.com/artists/27496-oliver-...
# ...                                                  ...
# 33536       https://www.songkick.com/artists/276130-acdc
# 33537            https://www.songkick.com/artists/230617
# 33538       https://www.songkick.com/artists/276130-acdc
# 33539       https://www.songkick.com/artists/276130-acdc
# 33540                                                NaN
#
#                                           bnfcatalogue  \
# 0                                                  NaN
# 1                                                  NaN
# 3      https://catalogue.bnf.fr/ark:/12148/cb13986530j
# 4                                                  NaN
# 6                                                  NaN
# ...                                                ...
# 33536  https://catalogue.bnf.fr/ark:/12148/cb13901479r
# 33537  https://catalogue.bnf.fr/ark:/12148/cb139048140
# 33538  https://catalogue.bnf.fr/ark:/12148/cb13901479r
# 33539  https://catalogue.bnf.fr/ark:/12148/cb13901479r
# 33540                                              NaN
#
#                                   dnb  \
# 0                                 NaN
# 1                                 NaN
# 3      http://d-nb.info/gnd/134861655
# 4                                 NaN
# 6      http://d-nb.info/gnd/134736583
# ...                               ...
# 33536  http://d-nb.info/gnd/1221288-X
# 33537  http://d-nb.info/gnd/5534784-8
# 33538  http://d-nb.info/gnd/1221288-X
# 33539  http://d-nb.info/gnd/1221288-X
# 33540                             NaN
#
#                                        instagram  \
# 0                                            NaN
# 1                                            NaN
# 3                                            NaN
# 4      https://www.instagram.com/thealexwoodard/
# 6                                            NaN
# ...                                          ...
# 33536            https://www.instagram.com/acdc/
# 33537                                        NaN
# 33538            https://www.instagram.com/acdc/
# 33539            https://www.instagram.com/acdc/
# 33540                                        NaN
#
#                                        youtube  \
# 0                                          NaN
# 1                                          NaN
# 3                                          NaN
# 4      //www.youtube.com/user/MoreForTheSender
# 6        //www.youtube.com/user/OliverMtukudzi
# ...                                        ...
# 33536          //www.youtube.com/user/acdcVEVO
# 33537                                      NaN
# 33538          //www.youtube.com/user/acdcVEVO
# 33539          //www.youtube.com/user/acdcVEVO
# 33540                                      NaN
#
#                                       facebook  \
# 0                                          NaN
# 1                                          NaN
# 3                                          NaN
# 4      https://www.facebook.com/thealexwoodard
# 6                                          NaN
# ...                                        ...
# 33536            https://www.facebook.com/acdc
# 33537                                      NaN
# 33538            https://www.facebook.com/acdc
# 33539            https://www.facebook.com/acdc
# 33540                                      NaN
#
#                                 twitter                          bandsintown  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# 6      https://twitter.com/tukuofficial  https://www.bandsintown.com/a/60617
# ...                                 ...                                  ...
# 33536         https://twitter.com/AC_DC  https://www.bandsintown.com/a/26647
# 33537                               NaN                                  NaN
# 33538         https://twitter.com/AC_DC  https://www.bandsintown.com/a/26647
# 33539         https://twitter.com/AC_DC  https://www.bandsintown.com/a/26647
# 33540                               NaN                                  NaN
#
#                                                 amazon  \
# 0                                                  NaN
# 1                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 6      //www.amazon.fr/-/e/B000APG3BU?tag=music083d-21
# ...                                                ...
# 33536                                              NaN
# 33537                                              NaN
# 33538                                              NaN
# 33539                                              NaN
# 33540                                              NaN
#
#                                            genius  \
# 0                                             NaN
# 1                                             NaN
# 3                                             NaN
# 4                                             NaN
# 6      https://genius.com/artists/Oliver-mtukudzi
# ...                                           ...
# 33536            https://genius.com/artists/Ac-dc
# 33537                                         NaN
# 33538            https://genius.com/artists/Ac-dc
# 33539            https://genius.com/artists/Ac-dc
# 33540                                         NaN
#
#                                        imdb  \
# 0                                       NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 6      https://www.imdb.com/name/nm0616186/
# ...                                     ...
# 33536  https://www.imdb.com/name/nm0009540/
# 33537  https://www.imdb.com/name/nm2135108/
# 33538  https://www.imdb.com/name/nm0009540/
# 33539  https://www.imdb.com/name/nm0009540/
# 33540                                   NaN
#
#                                           lastfm  \
# 0                                            NaN
# 1                                            NaN
# 3                                            NaN
# 4                                            NaN
# 6      https://www.last.fm/music/Oliver+Mtukudzi
# ...                                          ...
# 33536          https://www.last.fm/music/AC%2FDC
# 33537                                        NaN
# 33538          https://www.last.fm/music/AC%2FDC
# 33539          https://www.last.fm/music/AC%2FDC
# 33540                                        NaN
#
#                                            rateyourmusic  \
# 0                                                    NaN
# 1                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 6       https://rateyourmusic.com/artist/oliver-mtukudzi
# ...                                                  ...
# 33536             https://rateyourmusic.com/artist/ac_dc
# 33537  https://rateyourmusic.com/artist/the_mamas_and...
# 33538             https://rateyourmusic.com/artist/ac_dc
# 33539             https://rateyourmusic.com/artist/ac_dc
# 33540  https://rateyourmusic.com/artist/kahil_elzabar...
#
#                                       reverbnation  \
# 0                                              NaN
# 1                                              NaN
# 3                                              NaN
# 4                                              NaN
# 6      https://www.reverbnation.com/artist_3936035
# ...                                            ...
# 33536                                          NaN
# 33537                                          NaN
# 33538                                          NaN
# 33539                                          NaN
# 33540                                          NaN
#
#                                 secondhandsongs  \
# 0                                           NaN
# 1                                           NaN
# 3                                           NaN
# 4                                           NaN
# 6      https://secondhandsongs.com/artist/14883
# ...                                         ...
# 33536   https://secondhandsongs.com/artist/1516
# 33537                                       NaN
# 33538   https://secondhandsongs.com/artist/1516
# 33539   https://secondhandsongs.com/artist/1516
# 33540                                       NaN
#
#                                                setlistfm  \
# 0                                                    NaN
# 1                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 6      https://www.setlist.fm/setlists/oliver-mtukudz...
# ...                                                  ...
# 33536  https://www.setlist.fm/setlists/acdc-23d6807b....
# 33537                                                NaN
# 33538  https://www.setlist.fm/setlists/acdc-23d6807b....
# 33539  https://www.setlist.fm/setlists/acdc-23d6807b....
# 33540                                                NaN
#
#                                         whosampled  \
# 0                                              NaN
# 1                                              NaN
# 3                                              NaN
# 4                                              NaN
# 6      https://www.whosampled.com/Oliver-Mtukudzi/
# ...                                            ...
# 33536             https://www.whosampled.com/ACDC/
# 33537                                          NaN
# 33538             https://www.whosampled.com/ACDC/
# 33539             https://www.whosampled.com/ACDC/
# 33540                                          NaN
#
#                                                 worldcat  \
# 0                                                    NaN
# 1                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 6      https://www.worldcat.org/identities/lccn-no000...
# ...                                                  ...
# 33536  https://www.worldcat.org/identities/lccn-n7801...
# 33537  https://www.worldcat.org/identities/lccn-n8521...
# 33538  https://www.worldcat.org/identities/lccn-n7801...
# 33539  https://www.worldcat.org/identities/lccn-n7801...
# 33540                                                NaN
#
#                                                   loc  \
# 0                                                 NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 6                                                 NaN
# ...                                               ...
# 33536  https://id.loc.gov/authorities/names/n78011846
# 33537  https://id.loc.gov/authorities/names/n85213584
# 33538  https://id.loc.gov/authorities/names/n78011846
# 33539  https://id.loc.gov/authorities/names/n78011846
# 33540                                             NaN
#
#                         myspace generasia vgmdb  \
# 0                           NaN       NaN   NaN
# 1                           NaN       NaN   NaN
# 3                           NaN       NaN   NaN
# 4                           NaN       NaN   NaN
# 6                           NaN       NaN   NaN
# ...                         ...       ...   ...
# 33536  https://myspace.com/acdc       NaN   NaN
# 33537                       NaN       NaN   NaN
# 33538  https://myspace.com/acdc       NaN   NaN
# 33539  https://myspace.com/acdc       NaN   NaN
# 33540                       NaN       NaN   NaN
#
#                                             musiksammler  \
# 0                                                    NaN
# 1                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 6                                                    NaN
# ...                                                  ...
# 33536         https://www.musik-sammler.de/artist/ac-dc/
# 33537  https://www.musik-sammler.de/artist/the-mamas-...
# 33538         https://www.musik-sammler.de/artist/ac-dc/
# 33539         https://www.musik-sammler.de/artist/ac-dc/
# 33540  https://www.musik-sammler.de/artist/kahil-elza...
#
#                                         applemusic bandcamp vimeo  \
# 0                                              NaN      NaN   NaN
# 1                                              NaN      NaN   NaN
# 3                                              NaN      NaN   NaN
# 4                                              NaN      NaN   NaN
# 6                                              NaN      NaN   NaN
# ...                                            ...      ...   ...
# 33536    https://music.apple.com/us/artist/5040714      NaN   NaN
# 33537                                          NaN      NaN   NaN
# 33538    https://music.apple.com/us/artist/5040714      NaN   NaN
# 33539    https://music.apple.com/us/artist/5040714      NaN   NaN
# 33540  https://music.apple.com/gb/artist/152776636      NaN   NaN
#
#                                        amazonmusic mora  \
# 0                                              NaN  NaN
# 1                                              NaN  NaN
# 3                                              NaN  NaN
# 4                                              NaN  NaN
# 6                                              NaN  NaN
# ...                                            ...  ...
# 33536  https://music.amazon.com/artists/B00136B4M8  NaN
# 33537                                          NaN  NaN
# 33538  https://music.amazon.com/artists/B00136B4M8  NaN
# 33539  https://music.amazon.com/artists/B00136B4M8  NaN
# 33540                                          NaN  NaN
#
#                                                       no utanet  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# 6                                                    NaN    NaN
# ...                                                  ...    ...
# 33536     http://musicmoz.org/Bands_and_Artists/A/AC-DC/    NaN
# 33537  http://musicmoz.org/Bands_and_Artists/M/Mamas_...    NaN
# 33538     http://musicmoz.org/Bands_and_Artists/A/AC-DC/    NaN
# 33539     http://musicmoz.org/Bands_and_Artists/A/AC-DC/    NaN
# 33540                                                NaN    NaN
#
#       encyclopedisque youtubemusic weibo snac imslp openlibrary  \
# 0                 NaN          NaN   NaN  NaN   NaN         NaN
# 1                 NaN          NaN   NaN  NaN   NaN         NaN
# 3                 NaN          NaN   NaN  NaN   NaN         NaN
# 4                 NaN          NaN   NaN  NaN   NaN         NaN
# 6                 NaN          NaN   NaN  NaN   NaN         NaN
# ...               ...          ...   ...  ...   ...         ...
# 33536             NaN          NaN   NaN  NaN   NaN         NaN
# 33537             NaN          NaN   NaN  NaN   NaN         NaN
# 33538             NaN          NaN   NaN  NaN   NaN         NaN
# 33539             NaN          NaN   NaN  NaN   NaN         NaN
# 33540             NaN          NaN   NaN  NaN   NaN         NaN
#
#                                       trove ibdb classicalarchives  \
# 0                                       NaN  NaN               NaN
# 1                                       NaN  NaN               NaN
# 3                                       NaN  NaN               NaN
# 4                                       NaN  NaN               NaN
# 6                                       NaN  NaN               NaN
# ...                                     ...  ...               ...
# 33536   https://nla.gov.au/nla.party-783697  NaN               NaN
# 33537  https://nla.gov.au/nla.party-1016214  NaN               NaN
# 33538   https://nla.gov.au/nla.party-783697  NaN               NaN
# 33539   https://nla.gov.au/nla.party-783697  NaN               NaN
# 33540                                   NaN  NaN               NaN
#
#                                 soundcloud muzikum blog rockcomar  \
# 0                                      NaN     NaN  NaN       NaN
# 1                                      NaN     NaN  NaN       NaN
# 3                                      NaN     NaN  NaN       NaN
# 4                                      NaN     NaN  NaN       NaN
# 6                                      NaN     NaN  NaN       NaN
# ...                                    ...     ...  ...       ...
# 33536  https://soundcloud.com/acdcofficial     NaN  NaN       NaN
# 33537                                  NaN     NaN  NaN       NaN
# 33538  https://soundcloud.com/acdcofficial     NaN  NaN       NaN
# 33539  https://soundcloud.com/acdcofficial     NaN  NaN       NaN
# 33540                                  NaN     NaN  NaN       NaN
#
#       progarchives fortyfiveworlds animenewsnetwork muziekweb cinii  \
# 0              NaN             NaN              NaN       NaN   NaN
# 1              NaN             NaN              NaN       NaN   NaN
# 3              NaN             NaN              NaN       NaN   NaN
# 4              NaN             NaN              NaN       NaN   NaN
# 6              NaN             NaN              NaN       NaN   NaN
# ...            ...             ...              ...       ...   ...
# 33536          NaN             NaN              NaN       NaN   NaN
# 33537          NaN             NaN              NaN       NaN   NaN
# 33538          NaN             NaN              NaN       NaN   NaN
# 33539          NaN             NaN              NaN       NaN   NaN
# 33540          NaN             NaN              NaN       NaN   NaN
#
#       musicapopularcl anisongeneration                      fortyfivecat  \
# 0                 NaN              NaN                               NaN
# 1                 NaN              NaN                               NaN
# 3                 NaN              NaN                               NaN
# 4                 NaN              NaN                               NaN
# 6                 NaN              NaN                               NaN
# ...               ...              ...                               ...
# 33536             NaN              NaN  http://www.45cat.com/artist/acdc
# 33537             NaN              NaN                               NaN
# 33538             NaN              NaN  http://www.45cat.com/artist/acdc
# 33539             NaN              NaN  http://www.45cat.com/artist/acdc
# 33540             NaN              NaN                               NaN
#
#                           imvdb                          tidal baidu ocremix  \
# 0                           NaN                            NaN   NaN     NaN
# 1                           NaN                            NaN   NaN     NaN
# 3                           NaN                            NaN   NaN     NaN
# 4                           NaN                            NaN   NaN     NaN
# 6                           NaN                            NaN   NaN     NaN
# ...                         ...                            ...   ...     ...
# 33536  https://imvdb.com/n/acdc  //listen.tidal.com/artist/945   NaN     NaN
# 33537                       NaN                            NaN   NaN     NaN
# 33538  https://imvdb.com/n/acdc  //listen.tidal.com/artist/945   NaN     NaN
# 33539  https://imvdb.com/n/acdc  //listen.tidal.com/artist/945   NaN     NaN
# 33540                       NaN                            NaN   NaN     NaN
#
#                                     musixmatch  \
# 0                                          NaN
# 1                                          NaN
# 3                                          NaN
# 4                                          NaN
# 6                                          NaN
# ...                                        ...
# 33536  https://www.musixmatch.com/artist/AC-DC
# 33537                                      NaN
# 33538  https://www.musixmatch.com/artist/AC-DC
# 33539  https://www.musixmatch.com/artist/AC-DC
# 33540                                      NaN
#
#                                   napster qobuz spiritofrock ircam  \
# 0                                     NaN   NaN          NaN   NaN
# 1                                     NaN   NaN          NaN   NaN
# 3                                     NaN   NaN          NaN   NaN
# 4                                     NaN   NaN          NaN   NaN
# 6                                     NaN   NaN          NaN   NaN
# ...                                   ...   ...          ...   ...
# 33536  https://us.napster.com/artist/acdc   NaN          NaN   NaN
# 33537                                 NaN   NaN          NaN   NaN
# 33538  https://us.napster.com/artist/acdc   NaN          NaN   NaN
# 33539  https://us.napster.com/artist/acdc   NaN          NaN   NaN
# 33540                                 NaN   NaN          NaN   NaN
#
#       quebecinfomusique beatport psydb cdjapan utaitedb recochoku  \
# 0                   NaN      NaN   NaN     NaN      NaN       NaN
# 1                   NaN      NaN   NaN     NaN      NaN       NaN
# 3                   NaN      NaN   NaN     NaN      NaN       NaN
# 4                   NaN      NaN   NaN     NaN      NaN       NaN
# 6                   NaN      NaN   NaN     NaN      NaN       NaN
# ...                 ...      ...   ...     ...      ...       ...
# 33536               NaN      NaN   NaN     NaN      NaN       NaN
# 33537               NaN      NaN   NaN     NaN      NaN       NaN
# 33538               NaN      NaN   NaN     NaN      NaN       NaN
# 33539               NaN      NaN   NaN     NaN      NaN       NaN
# 33540               NaN      NaN   NaN     NaN      NaN       NaN
#
#       residentadvisor overture mixcloud junodownload  \
# 0                 NaN      NaN      NaN          NaN
# 1                 NaN      NaN      NaN          NaN
# 3                 NaN      NaN      NaN          NaN
# 4                 NaN      NaN      NaN          NaN
# 6                 NaN      NaN      NaN          NaN
# ...               ...      ...      ...          ...
# 33536             NaN      NaN      NaN          NaN
# 33537             NaN      NaN      NaN          NaN
# 33538             NaN      NaN      NaN          NaN
# 33539             NaN      NaN      NaN          NaN
# 33540             NaN      NaN      NaN          NaN
#
#                                     livefans bookbrainz lieder utamap   vk  \
# 0                                        NaN        NaN    NaN    NaN  NaN
# 1                                        NaN        NaN    NaN    NaN  NaN
# 3                                        NaN        NaN    NaN    NaN  NaN
# 4                                        NaN        NaN    NaN    NaN  NaN
# 6                                        NaN        NaN    NaN    NaN  NaN
# ...                                      ...        ...    ...    ...  ...
# 33536  https://www.livefans.jp/artists/21822        NaN    NaN    NaN  NaN
# 33537                                    NaN        NaN    NaN    NaN  NaN
# 33538  https://www.livefans.jp/artists/21822        NaN    NaN    NaN  NaN
# 33539  https://www.livefans.jp/artists/21822        NaN    NaN    NaN  NaN
# 33540                                    NaN        NaN    NaN    NaN  NaN
#
#       twitch pinterest                                      spiritofmetal  \
# 0        NaN       NaN                                                NaN
# 1        NaN       NaN                                                NaN
# 3        NaN       NaN                                                NaN
# 4        NaN       NaN                                                NaN
# 6        NaN       NaN                                                NaN
# ...      ...       ...                                                ...
# 33536    NaN       NaN  http://www.spirit-of-metal.com/groupe-groupe-A...
# 33537    NaN       NaN                                                NaN
# 33538    NaN       NaN  http://www.spirit-of-metal.com/groupe-groupe-A...
# 33539    NaN       NaN  http://www.spirit-of-metal.com/groupe-groupe-A...
# 33540    NaN       NaN                                                NaN
#
#       finnmusic rolldabeats vkdb dahr jlyric tower dailymotion archive  \
# 0           NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 1           NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 3           NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 4           NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 6           NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# ...         ...         ...  ...  ...    ...   ...         ...     ...
# 33536       NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 33537       NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 33538       NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 33539       NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
# 33540       NaN         NaN  NaN  NaN    NaN   NaN         NaN     NaN
#
#       jazzmusicarchives tiktok cpdl linkedin utaten directlyrics bigcartel  \
# 0                   NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 1                   NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 3                   NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 4                   NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 6                   NaN    NaN  NaN      NaN    NaN          NaN       NaN
# ...                 ...    ...  ...      ...    ...          ...       ...
# 33536               NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 33537               NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 33538               NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 33539               NaN    NaN  NaN      NaN    NaN          NaN       NaN
# 33540               NaN    NaN  NaN      NaN    NaN          NaN       NaN
#
#       patreon vocadb  ric dogmazic videogamin castalbums dhhu operabase  \
# 0         NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 1         NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 3         NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 4         NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 6         NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# ...       ...    ...  ...      ...        ...        ...  ...       ...
# 33536     NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 33537     NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 33538     NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 33539     NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
# 33540     NaN    NaN  NaN      NaN        NaN        NaN  NaN       NaN
#
#       mainlynorfolk thesession piosenki wikisource songfacts traxsource  \
# 0               NaN        NaN      NaN        NaN       NaN        NaN
# 1               NaN        NaN      NaN        NaN       NaN        NaN
# 3               NaN        NaN      NaN        NaN       NaN        NaN
# 4               NaN        NaN      NaN        NaN       NaN        NaN
# 6               NaN        NaN      NaN        NaN       NaN        NaN
# ...             ...        ...      ...        ...       ...        ...
# 33536           NaN        NaN      NaN        NaN       NaN        NaN
# 33537           NaN        NaN      NaN        NaN       NaN        NaN
# 33538           NaN        NaN      NaN        NaN       NaN        NaN
# 33539           NaN        NaN      NaN        NaN       NaN        NaN
# 33540           NaN        NaN      NaN        NaN       NaN        NaN
#
#       rockipedia kickstarter gutenberg theatricalia
# 0            NaN         NaN       NaN          NaN
# 1            NaN         NaN       NaN          NaN
# 3            NaN         NaN       NaN          NaN
# 4            NaN         NaN       NaN          NaN
# 6            NaN         NaN       NaN          NaN
# ...          ...         ...       ...          ...
# 33536        NaN         NaN       NaN          NaN
# 33537        NaN         NaN       NaN          NaN
# 33538        NaN         NaN       NaN          NaN
# 33539        NaN         NaN       NaN          NaN
# 33540        NaN         NaN       NaN          NaN
#
# [16556 rows x 126 columns]

# %%
df['has_links'] = (df.spotify.notna()|df.youtube.notna()|df.bandcamp.notna()|df.lastfm.notna()|df.wikipedia.notna())

# %%
df.to_pickle(f'{YEAR}/releases.pickle')

# %%
df = pd.read_pickle(f'{YEAR}/releases.pickle')

# %%
FIXES = {
    'https://open.spotify.com/album/33eUZ9K00JkqFCg8DRNeIC': 'https://open.spotify.com/artist/0JQAeDYaigl5nor0kUP44X',
    'https://open.spotify.com/artist/4LDRJyWHn88OpklMQ0HVQ5': 'https://open.spotify.com/artist/2pktDyTJxrLJo7dL2qT1pA',
    
}

def get_spotify_listeners(link):
    if pd.isna(link) or '/user/' in link:
        return None
    
    link = FIXES.get(link, link)

    resp = requests.get(link)
    page = BeautifulSoup(resp.text)
    listeners = page.find('meta', attrs={'name': 'description'})
    if not listeners:
        print(link)
        return 0
    
    listeners = listeners['content'].split()[-3]


    mult = {'K': 1000, 'M': 1000000}
    if listeners[-1] in mult:
        number = int(float(listeners[:-1]) * mult[listeners[-1]])
    else:
        # print(link)
        number = int(float(listeners))

    return number

def get_lastfm_listeners(link):
    link = '/'.join(link.split('/')[:5])
    if pd.isna(link):
        return None

    resp = requests.get(link)
    page = BeautifulSoup(resp.text)
    listeners = page.find('abbr', class_='js-abbreviated-counter')
    if not listeners:
        print(link)
        return 0
    
    listeners = listeners['title'].replace(',', '')
    return int(listeners)

# %%
spotify_links = df[df['spotify'].notna()]['spotify'].values
spotify_listeners = {}

# %%
for link in tqdm(spotify_links):
    if link in spotify_listeners:
        continue
    spotify_listeners[link] = get_spotify_listeners(link)
# Out:
#   0%|          | 0/9634 [00:00<?, ?it/s]
# https://open.spotify.com/artist/3XsLl5bKLvszmBjKahoye3
# https://open.spotify.com/artist/5lntHrcFictDwCXOpdwHE9
# https://open.spotify.com/artist/0X20O9P2OiPChrCBYStQPe
# https://open.spotify.com/artist/3vfvURSGZedbEUNt3PruCj
# https://open.spotify.com/artist/4zZwqW9MVgUhmpcVeFfPEy
# https://open.spotify.com/artist/68W5IWYUEsW0ahQS7LPp9x
# https://open.spotify.com/artist/5EkZih2ZseQG4hJ2cC0Yew
# https://open.spotify.com/artist/7rz2w4y86wgga7Z6nrJKty
# https://open.spotify.com/artist/2Mm87pumoq58SN6trDSBdv
# https://open.spotify.com/artist/4I9DdwiQL1fPfPsGtjd7p5
# https://open.spotify.com/artist/4LDRJyWHn88OpklMQ0HVQ5
# https://open.spotify.com/artist/39p2cjqAtQYpPDksq6D4NH
# https://open.spotify.com/artist/7lybaCk8qwGc2pl69Hz612
# https://open.spotify.com/artist/4u2wOdwLhuXyftoeae69yY
# https://open.spotify.com/artist/2p0Waz6D8QKzx1MeSlJEm8
# https://open.spotify.com/artist/20NsAIv2s2oL0WPDVYhdC5

# %%
reparse = [
    'https://open.spotify.com/artist/7wCjDgV6nqBsHguQXPAaIM',
    'https://open.spotify.com/artist/3Ri72CuuQSCLLkDRJgniFU',
    'https://open.spotify.com/artist/68W5IWYUEsW0ahQS7LPp9x',
    'https://open.spotify.com/artist/7rz2w4y86wgga7Z6nrJKty',
    'https://open.spotify.com/artist/2p0Waz6D8QKzx1MeSlJEm8',
    'https://open.spotify.com/artist/3SXDCIdqI1AR686ukKtKCq',
]

# bi-2 https://open.spotify.com/artist/3SXDCIdqI1AR686ukKtKCq
# dolphin https://open.spotify.com/artist/2pktDyTJxrLJo7dL2qT1pA

for link in tqdm(reparse):
    spotify_listeners[link] = get_spotify_listeners(link)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
with open(f'{YEAR}/spotify.json', 'w') as f:
    f.write(json.dumps(spotify_listeners))

# %%
df.loc[df['artist_name']=='Би-2', 'spotify'] = 'https://open.spotify.com/artist/3SXDCIdqI1AR686ukKtKCq'
df[df['artist_name']=='Би-2']['spotify']
# Out:
# 4726     https://open.spotify.com/artist/3SXDCIdqI1AR68...
# 10461    https://open.spotify.com/artist/3SXDCIdqI1AR68...
# 30874    https://open.spotify.com/artist/3SXDCIdqI1AR68...
# Name: spotify, dtype: object

# %%
df2 = pd.DataFrame(spotify_listeners.items(), columns=['spotify', 'spotify_listeners'])
df2
# Out:
#                                                 spotify  spotify_listeners
# 0     https://open.spotify.com/artist/2heZLxgJjmZjVP...            70700.0
# 1     https://open.spotify.com/artist/0HC2dfJHpORLT2...            93100.0
# 2     https://open.spotify.com/artist/7FQRbf8gbKw8KZ...           175600.0
# 3     https://open.spotify.com/artist/0kSHocNBxQeP9p...            81600.0
# 4     https://open.spotify.com/artist/0yaejWkRQYl6PA...             3300.0
# ...                                                 ...                ...
# 4081  https://open.spotify.com/artist/711MCceyCBcFnz...         22800000.0
# 4082  https://open.spotify.com/artist/3U2U4TR03ZuSts...            99200.0
# 4083  https://open.spotify.com/artist/1bs7HoMkSyQwco...          5300000.0
# 4084  https://open.spotify.com/artist/0AuhzXNEVx1LGy...              547.0
# 4085  https://open.spotify.com/artist/3SXDCIdqI1AR68...           504900.0
#
# [4086 rows x 2 columns]

# %%
df = df.merge(df2, on='spotify', how='left')

# %%
lastfm_links = df[df['lastfm'].notna()]['lastfm'].values
lastfm_listeners = {}

# %%
for link in tqdm(lastfm_links):
    if link in lastfm_listeners:
        continue
    lastfm_listeners[link] = get_lastfm_listeners(link)

# %%
with open(f'{YEAR}/lastfm.json', 'w') as f:
    f.write(json.dumps(lastfm_listeners))

# %%
df2 = pd.DataFrame(lastfm_listeners.items(), columns=['lastfm', 'lastfm_listeners'])
df2

# %%
df = df.merge(df2, on='lastfm', how='left')

# %%
df['listeners'] = np.nanmax(df[['spotify_listeners', 'lastfm_listeners']], axis=1)
df
# Out:
# /tmp/ipykernel_14552/3106870311.py:1: RuntimeWarning: All-NaN axis encountered
#   df['listeners'] = np.nanmax(df[['spotify_listeners', 'lastfm_listeners']], axis=1)
#       release_type        release_name  \
# 0            Album      Lenka Dusilová
# 1            Album  Ça parle au diable
# 2            Album   Afterlife Kingdom
# 3            Album         Call Me Al!
# 4            Album   Nowhere Near Here
# ...            ...                 ...
# 33536       Single     Stiff Upper Lip
# 33537        Album  California Dreamin
# 33538           EP     Stiff Upper Lip
# 33539       Single     Satellite Blues
# 33540        Album   Africa N’da Blues
#
#                                             release_link  \
# 0      /release-group/2a23335a-5590-30c3-b25c-884cabe...
# 1      /release-group/71058210-8408-3aed-8878-3ad2e4a...
# 2      /release-group/3d648595-b55e-3968-a333-390d257...
# 3      /release-group/53dd9a96-e8ea-3200-abee-8911b55...
# 4      /release-group/a8ce8cf1-3def-30af-b387-65acd97...
# ...                                                  ...
# 33536  /release-group/5259dd42-3636-31c5-9311-d011b25...
# 33537  /release-group/ed938e59-3c6c-4d64-8df2-55984bd...
# 33538  /release-group/61f736e8-b7dd-48c6-b164-1d2f91c...
# 33539  /release-group/9d7d4079-3c30-3352-ba6e-2bb479b...
# 33540  /release-group/1a3a5e70-dfae-4c45-9708-a42722a...
#
#                         artist_name  \
# 0                    Lenka Dusilová
# 1                         Mes Aïeux
# 2                 Satanic Slaughter
# 3                       Alain Caron
# 4                      Alex Woodard
# ...                             ...
# 33536                         AC/DC
# 33537         The Mamas & the Papas
# 33538                         AC/DC
# 33539                         AC/DC
# 33540  Kahil El’Zabar’s Ritual Trio
#
#                                         artist_link  \
# 0      /artist/4d60cb9c-81e2-4ae2-9976-b640b545a303
# 1      /artist/a320d461-a689-4946-a686-70a6eaebdffb
# 2      /artist/1fd06f01-fb68-43ee-a392-af7336250df1
# 3      /artist/f95594fd-8ba6-4540-8854-7c149153a891
# 4      /artist/265b1f16-f15c-484f-a6b7-2be20dcf6a9e
# ...                                             ...
# 33536  /artist/66c662b6-6e2f-4930-8610-912e24c63ed1
# 33537  /artist/ff294730-0315-440d-a543-54005779c15b
# 33538  /artist/66c662b6-6e2f-4930-8610-912e24c63ed1
# 33539  /artist/66c662b6-6e2f-4930-8610-912e24c63ed1
# 33540  /artist/caa2c74d-55d8-4c54-bcbd-85c9fd7b575c
#
#                                       discogs  \
# 0       https://www.discogs.com/artist/557781
# 1      https://www.discogs.com/artist/2209784
# 2       https://www.discogs.com/artist/278391
# 3       https://www.discogs.com/artist/267096
# 4       https://www.discogs.com/artist/732422
# ...                                       ...
# 33536    https://www.discogs.com/artist/84752
# 33537   https://www.discogs.com/artist/230387
# 33538    https://www.discogs.com/artist/84752
# 33539    https://www.discogs.com/artist/84752
# 33540   https://www.discogs.com/artist/322784
#
#                                            wikipedia  \
# 0        //en.wikipedia.org/wiki/Lenka_Dusilov%C3%A1
# 1             //en.wikipedia.org/wiki/Mes_A%C3%AFeux
# 2                                                NaN
# 3      //en.wikipedia.org/wiki/Alain_Caron_(bassist)
# 4                                                NaN
# ...                                              ...
# 33536                                            NaN
# 33537                                            NaN
# 33538                                            NaN
# 33539                                            NaN
# 33540                                            NaN
#
#                                    viaf                          wikidata  \
# 0       https://viaf.org/viaf/85482923/  //www.wikidata.org/wiki/Q3490011
# 1                                   NaN  //www.wikidata.org/wiki/Q2567516
# 2                                   NaN  //www.wikidata.org/wiki/Q2705128
# 3       https://viaf.org/viaf/37110944/   //www.wikidata.org/wiki/Q714021
# 4                                   NaN                               NaN
# ...                                 ...                               ...
# 33536  https://viaf.org/viaf/144189738/    //www.wikidata.org/wiki/Q27593
# 33537  https://viaf.org/viaf/229179345/   //www.wikidata.org/wiki/Q211277
# 33538  https://viaf.org/viaf/144189738/    //www.wikidata.org/wiki/Q27593
# 33539  https://viaf.org/viaf/144189738/    //www.wikidata.org/wiki/Q27593
# 33540                               NaN                               NaN
#
#                                       home  ... songfacts traxsource  \
# 0                                      NaN  ...       NaN        NaN
# 1                   http://mesaieux.qc.ca/  ...       NaN        NaN
# 2         http://hem.passagen.se/ztefdark/  ...       NaN        NaN
# 3      https://www.alaincaronofficial.com/  ...       NaN        NaN
# 4                                      NaN  ...       NaN        NaN
# ...                                    ...  ...       ...        ...
# 33536                 http://www.acdc.com/  ...       NaN        NaN
# 33537                                  NaN  ...       NaN        NaN
# 33538                 http://www.acdc.com/  ...       NaN        NaN
# 33539                 http://www.acdc.com/  ...       NaN        NaN
# 33540                                  NaN  ...       NaN        NaN
#
#       rockipedia kickstarter gutenberg theatricalia has_links  \
# 0            NaN         NaN       NaN          NaN      True
# 1            NaN         NaN       NaN          NaN      True
# 2            NaN         NaN       NaN          NaN     False
# 3            NaN         NaN       NaN          NaN      True
# 4            NaN         NaN       NaN          NaN      True
# ...          ...         ...       ...          ...       ...
# 33536        NaN         NaN       NaN          NaN      True
# 33537        NaN         NaN       NaN          NaN      True
# 33538        NaN         NaN       NaN          NaN      True
# 33539        NaN         NaN       NaN          NaN      True
# 33540        NaN         NaN       NaN          NaN      True
#
#       lastfm_listeners spotify_listeners   listeners
# 0                  NaN               NaN         NaN
# 1                  NaN           70700.0     70700.0
# 2                  NaN               NaN         NaN
# 3                  NaN               NaN         NaN
# 4                  NaN               NaN         NaN
# ...                ...               ...         ...
# 33536        3189422.0        22800000.0  22800000.0
# 33537              NaN         5300000.0   5300000.0
# 33538        3189422.0        22800000.0  22800000.0
# 33539        3189422.0        22800000.0  22800000.0
# 33540              NaN             547.0       547.0
#
# [33541 rows x 130 columns]

# %%
df.to_pickle(f'{YEAR}/releases.pickle')
df.fillna('').to_excel(f'{YEAR}/releases.xlsx')
